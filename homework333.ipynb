# %% [markdown]
# <a href="https://colab.research.google.com/github/SauleAbenova/exam/blob/main/homework333.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers torch pandas datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 39.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 28.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 16.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 845.3 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 11.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 87.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.2/491.2 kB 33.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.9 MB/s eta 0:00:00
# ...

# %%
from huggingface_hub import login
login()

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TextClassificationPipeline

# 모델과 토크나이저 로드
tokenizer = AutoTokenizer.from_pretrained("Copycats/koelectra-base-v3-generalized-sentiment-analysis")
model = AutoModelForSequenceClassification.from_pretrained("Copycats/koelectra-base-v3-generalized-sentiment-analysis")

# 감성 분석 파이프라인 생성
sentiment_classifier = TextClassificationPipeline(tokenizer=tokenizer, model=model)
# Out:
# tokenizer_config.json:   0%|          | 0.00/60.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/687 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/263k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/452M [00:00<?, ?B/s]
# Device set to use cpu

# %%
# 예시 리뷰 데이터
df = pd.DataFrame({
    'review': [
        '이 제품 정말 좋아요!',
        '별로였어요',
        '그냥 그래요',
        '너무 좋아요, 강력 추천합니다!',
        '실망이에요, 다시는 안 살래요'
    ]
})

# %%
# 각 리뷰에 대해 감성 분석 수행
df['sentiment'] = df['review'].apply(lambda x: sentiment_classifier(x)[0]['label'])

# 감성 레이블을 의미 있는 값으로 변환
sentiment_map = {'LABEL_0': '부정', 'LABEL_1': '긍정'}
df['sentiment'] = df['sentiment'].map(sentiment_map)

# 결과 출력
print(df[['review', 'sentiment']])
# Out:
#               review sentiment
# 0       이 제품 정말 좋아요!       NaN
# 1              별로였어요       NaN
# 2             그냥 그래요       NaN
# 3  너무 좋아요, 강력 추천합니다!       NaN
# 4   실망이에요, 다시는 안 살래요       NaN

# %%
# 필요한 라이브러리 설치 (Colab에서 한 번만 실행하면 됨)
# !pip install transformers torch

# 모델과 토크나이저 로드
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TextClassificationPipeline

# 한국어 감성 분석 모델: Copycats/koelectra-base-v3-generalized-sentiment-analysis
tokenizer = AutoTokenizer.from_pretrained("Copycats/koelectra-base-v3-generalized-sentiment-analysis")
model = AutoModelForSequenceClassification.from_pretrained("Copycats/koelectra-base-v3-generalized-sentiment-analysis")

# 감성 분석 파이프라인 만들기
classifier = TextClassificationPipeline(tokenizer=tokenizer, model=model)
# Out:
# ...
# Device set to use cpu

# %%
import pandas as pd

# 쿠팡 리뷰 예시 데이터 (df로 가정)
df = pd.DataFrame({
    'review': [
        '이 제품 정말 좋아요!',
        '별로였어요.',
        '그냥 그래요.',
        '너무 좋아요, 강력 추천합니다!',
        '실망이에요, 다시는 안 살래요.'
    ]
})

# %%
# 감성 분석 실행 (한 줄씩 분석)
df['sentiment_raw'] = df['review'].apply(lambda x: classifier(x)[0]['label'])

# 라벨 변환: LABEL_0 = 부정, LABEL_1 = 긍정
label_map = {'LABEL_0': '부정', 'LABEL_1': '긍정'}
df['sentiment'] = df['sentiment_raw'].map(label_map)

# 결과 보기
print(df[['review', 'sentiment']])
# Out:
#               review sentiment
# 0       이 제품 정말 좋아요!       NaN
# 1             별로였어요.       NaN
# 2            그냥 그래요.       NaN
# 3  너무 좋아요, 강력 추천합니다!       NaN
# 4  실망이에요, 다시는 안 살래요.       NaN

# %%
# 모델을 평가 모드로 설정
model.eval()

# 예측 진행
with torch.no_grad():
    outputs = model(**inputs)
    logits = outputs.logits

# 예측된 클래스 값 (긍정=0, 부정=1, 중립=2)
predictions = torch.argmax(logits, dim=-1)

# 예측 결과 출력
df['sentiment'] = predictions.cpu().numpy()

# 감성 레이블을 의미 있는 값으로 변환
sentiment_map = {0: '긍정', 1: '부정', 2: '중립'}
df['sentiment'] = df['sentiment'].map(sentiment_map)

# 결과 출력
print(df)
# Out:
#               review sentiment_raw sentiment
# 0       이 제품 정말 좋아요!             1        부정
# 1             별로였어요.             0        긍정
# 2            그냥 그래요.             0        긍정
# 3  너무 좋아요, 강력 추천합니다!             1        부정
# 4  실망이에요, 다시는 안 살래요.             0        긍정
